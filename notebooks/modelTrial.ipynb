# %%
import sys
import os

# Get the absolute path to the directory one level up (the project root)
root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)

# %%
from src.data_loader import load_mnist
from src.logistic_regression import LogisticRegression
from src.utils import print_metrics, plot_confusion_matrix

# %%
X_train, X_test, y_train, y_test = load_mnist()
#X_test[1]
print(y_train)
# Out:
# [0 0 1 ... 0 0 0]

# %%
model1 = LogisticRegression(alpha=0.1, num_iter=200)
model1.fit(X_train, y_train)
y_pred_train1 = model1.predict(X_train)
y_pred_test1= model1.predict(X_test)
print_metrics(y_train, y_pred_train1, y_test, y_pred_test1)
plot_confusion_matrix(y_test, y_pred_test1, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9369642857142857
# Test Accuracy:  0.9375714285714286
# Train Precision:  0.8125806451612904
# Test Precision:  0.8165137614678899
# Train Recall:  0.46068032187271396
# Test Recall:  0.4591009579955785
# Train F1 Score:  0.5880018674136321
# Test F1 Score:  0.5877358490566038

# %%
model2 = LogisticRegression(alpha=0.1, num_iter=300)
model2.fit(X_train, y_train)
y_pred_train2 = model2.predict(X_train)
y_pred_test2= model2.predict(X_test)
print_metrics(y_train, y_pred_train2, y_test, y_pred_test2)
plot_confusion_matrix(y_test, y_pred_test2, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9421071428571428
# Test Accuracy:  0.9429285714285714
# Train Precision:  0.8170940170940171
# Test Precision:  0.8184931506849316
# Train Recall:  0.5245062179956108
# Test Recall:  0.5283714075165807
# Train F1 Score:  0.6388950768545333
# Test F1 Score:  0.6421854008060904

# %%
model3= LogisticRegression(alpha=0.2, num_iter=200)
model3.fit(X_train, y_train)
y_pred_train3 = model3.predict(X_train)
y_pred_test3= model3.predict(X_test)
print_metrics(y_train, y_pred_train3, y_test, y_pred_test3)
plot_confusion_matrix(y_test, y_pred_test3, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9444107142857143
# Test Accuracy:  0.9457857142857143
# Train Precision:  0.8155990351112302
# Test Precision:  0.8235930735930735
# Train Recall:  0.5565106071689832
# Test Recall:  0.5607958732498157
# Train F1 Score:  0.661593651483857
# Test F1 Score:  0.6672512056115739

# %%
model4= LogisticRegression(alpha=0.2, num_iter=300)
model4.fit(X_train, y_train)
y_pred_train4 = model4.predict(X_train)
y_pred_test4= model4.predict(X_test)
print_metrics(y_train, y_pred_train4, y_test, y_pred_test4)
plot_confusion_matrix(y_test, y_pred_test4, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9476428571428571
# Test Accuracy:  0.9486428571428571
# Train Precision:  0.8242966751918158
# Test Precision:  0.8302277432712215
# Train Recall:  0.5894294074615948
# Test Recall:  0.5910095799557848
# Train F1 Score:  0.6873533802516528
# Test F1 Score:  0.6904864399483427

# %%
from sklearn.decomposition import PCA
X_train_pca1 = PCA(n_components=60).fit_transform(X_train)
X_test_pca1 = PCA(n_components=60).fit_transform(X_test)
model5= LogisticRegression(alpha=0.2, num_iter=300)
model5.fit(X_train_pca1, y_train)
y_pred_train5 = model5.predict(X_train_pca1)
y_pred_test5= model5.predict(X_test_pca1)
print_metrics(y_train, y_pred_train5, y_test, y_pred_test5)
plot_confusion_matrix(y_test, y_pred_test5, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9553571428571429
# Test Accuracy:  0.9395714285714286
# Train Precision:  0.873427277302466
# Test Precision:  0.7786259541984732
# Train Recall:  0.6347841989758596
# Test Recall:  0.5261606484893147
# Train F1 Score:  0.7352255877991951
# Test F1 Score:  0.6279683377308707

# %%
X_train_pca2 = PCA(n_components=50).fit_transform(X_train)
X_test_pca2 = PCA(n_components=50).fit_transform(X_test)
model6= LogisticRegression(alpha=0.2, num_iter=300)
model6.fit(X_train_pca2, y_train)
y_pred_train6 = model6.predict(X_train_pca2)
y_pred_test6= model6.predict(X_test_pca2)
print_metrics(y_train, y_pred_train6, y_test, y_pred_test6)
plot_confusion_matrix(y_test, y_pred_test6, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9549107142857143
# Test Accuracy:  0.9392142857142857
# Train Precision:  0.8722489248671895
# Test Precision:  0.7774122807017544
# Train Recall:  0.6305779078273592
# Test Recall:  0.522476050110538
# Train F1 Score:  0.7319817429147649
# Test F1 Score:  0.624944909651829

# %%
model7= LogisticRegression(alpha=0.2, num_iter=400)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9497142857142857
# Test Accuracy:  0.9508571428571428
# Train Precision:  0.8298507462686567
# Test Precision:  0.8334995014955134
# Train Recall:  0.6100950987564009
# Test Recall:  0.6160648489314665
# Train F1 Score:  0.7032040472175379
# Test F1 Score:  0.7084745762711865

# %%
model7= LogisticRegression(alpha=0.3, num_iter=400)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9524642857142858
# Test Accuracy:  0.954
# Train Precision:  0.8387252535007242
# Test Precision:  0.8471275559883155
# Train Recall:  0.6353328456474031
# Test Recall:  0.6411201179071481
# Train F1 Score:  0.722996878251821
# Test F1 Score:  0.7298657718120806

# %%
model7= LogisticRegression(alpha=0.5, num_iter=400)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9557142857142857
# Test Accuracy:  0.9562142857142857
# Train Precision:  0.8523584905660377
# Test Precision:  0.8556405353728489
# Train Recall:  0.660936356986101
# Test Recall:  0.6595431098010317
# Train F1 Score:  0.7445405850844664
# Test F1 Score:  0.7449022055763629

# %%
model7= LogisticRegression(alpha=0.8, num_iter=400)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9573214285714285
# Test Accuracy:  0.9575
# Train Precision:  0.8577405857740585
# Test Precision:  0.8607954545454546
# Train Recall:  0.674835405998537
# Test Recall:  0.6698599852616065
# Train F1 Score:  0.7553735926305015
# Test F1 Score:  0.7534189805221716

# %%
model7= LogisticRegression(alpha=0.8, num_iter=1000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9596607142857143
# Test Accuracy:  0.9592142857142857
# Train Precision:  0.8634201585503963
# Test Precision:  0.8632162661737524
# Train Recall:  0.6971470373079737
# Test Recall:  0.68828297715549
# Train F1 Score:  0.7714256804613984
# Test F1 Score:  0.7658876588765887

# %%
model7= LogisticRegression(alpha=1, num_iter=1000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9602321428571429
# Test Accuracy:  0.9596428571428571
# Train Precision:  0.8648952938527359
# Test Precision:  0.8639705882352942
# Train Recall:  0.7024506217995611
# Test Recall:  0.6927044952100221
# Train F1 Score:  0.7752548188515491
# Test F1 Score:  0.7689161554192229

# %%
model7= LogisticRegression(alpha=1, num_iter=10000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9617678571428572
# Test Accuracy:  0.9599285714285715
# Train Precision:  0.8669755129053607
# Test Precision:  0.852212389380531
# Train Recall:  0.7187271397220191
# Test Recall:  0.709653647752395
# Train F1 Score:  0.785921407859214
# Test F1 Score:  0.7744270205066345

# %%
model7= LogisticRegression(alpha=2.1, num_iter=5000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9464107142857143
# Test Accuracy:  0.9473571428571429
# Train Precision:  0.6786386676321506
# Test Precision:  0.6874244256348246
# Train Recall:  0.8569861009509876
# Test Recall:  0.8378776713338246
# Train F1 Score:  0.757455750424311
# Test F1 Score:  0.7552308203254733

# %%
model7= LogisticRegression(alpha=1.1, num_iter=10000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9617857142857142
# Test Accuracy:  0.9599285714285715
# Train Precision:  0.8668430335097002
# Test Precision:  0.852212389380531
# Train Recall:  0.7190929041697147
# Test Recall:  0.709653647752395
# Train F1 Score:  0.7860855657736905
# Test F1 Score:  0.7744270205066345

# %%
model7= LogisticRegression(alpha=1.2, num_iter=10000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9618928571428571
# Test Accuracy:  0.9599285714285715
# Train Precision:  0.867828773168579
# Test Precision:  0.8515901060070671
# Train Recall:  0.7192757863935626
# Test Recall:  0.7103905674281503
# Train F1 Score:  0.7866
# Test F1 Score:  0.7746082764162314

# %%
model7= LogisticRegression(alpha=1.5, num_iter=10000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9592321428571429
# Test Accuracy:  0.9568571428571429
# Train Precision:  0.7911866886085207
# Test Precision:  0.7790956263899185
# Train Recall:  0.7913313825896123
# Test Recall:  0.7745025792188651
# Train F1 Score:  0.7912590289841821
# Test F1 Score:  0.7767923133776792

# %%
model7= LogisticRegression(alpha=1.3, num_iter=10000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9619285714285715
# Test Accuracy:  0.96
# Train Precision:  0.8678870754300838
# Test Precision:  0.851721094439541
# Train Recall:  0.7196415508412582
# Test Recall:  0.7111274871039057
# Train F1 Score:  0.7868426314737053
# Test F1 Score:  0.7751004016064257

# %%
model7= LogisticRegression(alpha=1.3, num_iter=15000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9619821428571429
# Test Accuracy:  0.9594285714285714
# Train Precision:  0.867165163844293
# Test Precision:  0.8463564530289728
# Train Recall:  0.721104608632041
# Test Recall:  0.7103905674281503
# Train F1 Score:  0.7874188716924613
# Test F1 Score:  0.7724358974358975

# %%
model7= LogisticRegression(alpha=1.1, num_iter=15000)
model7.fit(X_train, y_train)
y_pred_train7 = model7.predict(X_train)
y_pred_test7= model7.predict(X_test)
print_metrics(y_train, y_pred_train7, y_test, y_pred_test7)
plot_confusion_matrix(y_test, y_pred_test7, "Confusion Matrix (Logistic Regression)")
# Out:
# Train Accuracy:  0.9618571428571429
# Test Accuracy:  0.9597142857142857
# Train Precision:  0.8671220802115469
# Test Precision:  0.8493392070484581
# Train Recall:  0.7196415508412582
# Test Recall:  0.7103905674281503
# Train F1 Score:  0.7865280831501099
# Test F1 Score:  0.7736757624398074
